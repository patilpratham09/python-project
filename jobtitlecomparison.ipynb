# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

# %%
data = pd.read_csv("C:/Users/Pratham Patil/Analysis data.csv")

# %%
data.head()
# Out:
#                                            title  \
# 0                                Finance Analyst
# 1              Senior Business Financial Analyst
# 2                                Finance Analyst
# 3                       Business Finance Analyst
# 4  Senior Finance Analyst-Reporting and Analysis
#
#                           industry/department                   company  \
# 0                             Various/Finance               oliver plus
# 1                                     Finance                LRQA Group
# 2  Financial Technology and Retail Technology                NCR Atleos
# 3        Data Analytics and Experience Design  Techmatters Technologies
# 4                       Professional Services             Ernst & Young
#
#                                               skills  \
# 0  1. Finance experience\n2. Advanced Excel\n3. P...
# 1  1.Power BI\n2.SAP\n3.Microsoft Office\n4.Finan...
# 2  1. Financial Analysis\n2. Pricing\n3. Risk Ass...
# ...

# %%
data = data[['title','skills','responsibility']]
data = data.dropna()

# %%
data['skills'] = data['skills'].str.split('\n').apply(lambda x: [skill.strip() for skill in x])

# %%
soft_skills_list = ['communication', 'teamwork', 'problem solving', 'leadership', 'time management', 'adaptability', 'creativity']
tools_languages_list = ['excel', 'sql', 'python', 'r', 'tableau', 'power bi', 'sap', 'microsoft office', 'javascript', 'java']

# %%
def clean_split_skills(skills_str):
    if isinstance(skills_str, str):
        return [skill.strip().lower() for skill in skills_str.split('\n') if skill.strip()]
    return []

# %%
def categorize_skills(skills):
    soft_skills = []
    tools_languages = []
    for skill in skills:
        if any(soft_skill in skill for soft_skill in soft_skills_list):
            soft_skills.append(skill)
        elif any(tool in skill for tool in tools_languages_list):
            tools_languages.append(skill)
    return soft_skills, tools_languages
